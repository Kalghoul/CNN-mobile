# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalghoul/CNN-mobile/blob/main/CNN_Saad_github-v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Standard library
import os
import shutil
import random as python_random
from collections import Counter
from dataclasses import dataclass

# Third-party libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from scipy import stats
from scipy.signal import butter, lfilter
from scipy.stats import mode

from sklearn.model_selection import train_test_split, GroupKFold, KFold, StratifiedGroupKFold
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import (
    precision_recall_fscore_support,
    roc_auc_score,
    roc_curve,
    auc,
    f1_score,
    accuracy_score
)

# TensorFlow / Keras
from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import (
    Input,
    Conv1D,
    Flatten,
    MaxPooling1D,
    Dropout,
    BatchNormalization,
    GlobalAveragePooling1D,
    AveragePooling1D,
    LSTM,
    concatenate,
    GRU,
    Bidirectional,
    Embedding,
    LayerNormalization,
    MultiHeadAttention,
    Dense,
    Activation,
    DepthwiseConv1D,
    Add,
    MultiHeadAttention
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Recall
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger
from tensorflow.keras.backend import clear_session
import tensorflow.keras.backend as K

# %%
clear_session()

# %%
np.random.seed(42)
python_random.seed(42)
tf.random.set_seed(42)

# %%
# New segment and slide lengths
segment_length_sec = 60
slide_length_sec = 5
sf_BVP = 64  # Sampling frequency for the BVP data of the PPGE dataset
feat_sf64 = ['bvp']

# Number of samples per segment and slide
# Converting the seconds into samples based on the frenquency sampling rate used by the device to capture the BVP data
segment_length_samples = segment_length_sec * sf_BVP
slide_length_samples = slide_length_sec * sf_BVP

# %%
df_segments = pd.read_pickle('/content/drive/MyDrive/i2mtc-2026/Dataframes/WARM-VR_df_segments_Olfactory_1_relx_exper_28-participants_60s_5s.pkl')

# %%
print("shape of original df: ", df_segments.shape )
# Step 1: Extract unique SubjectIDs
unique_subject_ids = df_segments['SubjectID'].unique()
print("unique_subject_ids of original", unique_subject_ids)

# Step 2: Shuffle the unique SubjectIDs
rng = np.random.RandomState(42)  # Create a random state object with seed 42
rng.shuffle(unique_subject_ids)  # Use the random state object to shuffle

# Step 3: Create a new DataFrame sorted according to the shuffled SubjectIDs
shuffled_df_segments_combined = pd.concat([df_segments[df_segments['SubjectID'] == sid] for sid in unique_subject_ids], ignore_index=True)

print("unique_subject_ids of new", shuffled_df_segments_combined['SubjectID'].unique())

# Verify the shuffling
print("shape of new df: ", shuffled_df_segments_combined.shape )
print(shuffled_df_segments_combined.head())
# Out:
# shape of original df:  (6527, 5)
# unique_subject_ids of original [14 21  5 31 10  6 30 24 29 28  4 17 11 20 27 18 15 23  2  3  7 26 22 25
#  12 16 13  8]
# unique_subject_ids of new [28 16 29 26 14 11 23 22 17 20 18 21 10  6  5 15 25 31 13 12  2  8  7 24
#   4 27  3 30]
# shape of new df:  (6527, 5)
#                                              Segment  ArousalLabel  \
# 0  [0.09251861177927405, 0.08855483433770503, 0.0...             0
# 1  [-0.2037737519780108, 0.15841641174535917, 0.2...             0
# 2  [-0.12558824194306173, -0.152938306289888, -0....             0
# 3  [0.1715959717385762, 0.16465936121583036, 0.14...             0
# 4  [-0.37778358166289117, -0.3560819001703007, -0...             0
#
#    ValenceLabel  RelaxationLabel  SubjectID
# 0             1                1         28
# 1             1                1         28
# 2             1                1         28
# 3             1                1         28
# 4             1                1         28

# %%
train_val_df = pd.read_pickle('/content/drive/MyDrive/i2mtc-2026/Dataframes/WARM-VR_train_val_df_Olfactory_1_relx_exper_28-participants_60s_5s.pkl')
print("Train/Val shape:", train_val_df.shape)

test_df = pd.read_pickle('/content/drive/MyDrive/i2mtc-2026/Dataframes/WARM-VR_test_df_Olfactory_1_relx_exper_28-participants_60s_5s.pkl')
print("Test_df shape:", test_df.shape)
# Out:
# Train/Val shape: (5244, 5)
# Test_df shape: (1283, 5)

# %%
def cnn_60s_model(n_feat):
    # Building a Convolutional Neural Network (CNN) model using Sequential API

    model = Sequential()  # Initialize the model as a sequential model

    # First Convolutional Layer
    model.add(Conv1D(filters=8, kernel_size=64, strides=4, padding='same',
                     activation='relu', input_shape=(n_feat, 1)))
    # - Conv1D layer with 8 filters, a kernel size of 64, and stride of 4
    # - 'same' padding ensures output size is the same as input size
    # - ReLU activation is applied to introduce non-linearity
    # - The input shape is set to (n_feat, 1), where n_feat is the number of features

    model.add(MaxPooling1D(pool_size=4))
    # - MaxPooling layer with a pool size of 4 reduces the dimensionality by down-sampling

    model.add(BatchNormalization())
    # - BatchNormalization layer normalizes the output of the previous layer,
    #   which speeds up training and provides regularization

    # 50% Dropout Layer
    model.add(Dropout(0.5))
    # - Dropout layer with a dropout rate of 0.5 randomly drops 50% of the neurons during training
    #   to prevent overfitting

    # Second Convolutional Layer
    model.add(Conv1D(filters=16, kernel_size=32, strides=2, activation='relu', padding='same'))
    # - Conv1D layer with 16 filters, a kernel size of 32, and stride of 2
    # - 'same' padding is used again, with ReLU activation

    model.add(MaxPooling1D(pool_size=4))
    # - MaxPooling layer with a pool size of 4 further reduces dimensionality

    model.add(BatchNormalization())
    # - BatchNormalization layer normalizes the output again for faster and more stable training

    # 50% Dropout Layer
    model.add(Dropout(0.5))
    # - Another Dropout layer with a rate of 0.5 to add further regularization and reduce overfitting

    # Third Convolutional Layer
    model.add(Conv1D(filters=8, kernel_size=16, strides=1, activation='relu', padding='same'))
    # - Conv1D layer with 8 filters, a kernel size of 16, and stride of 1
    # - 'same' padding is used again with ReLU activation

    model.add(MaxPooling1D(pool_size=4))
    # - MaxPooling layer with a pool size of 4 to further reduce the feature map size

    # Flatten and Fully Connected Layers
    model.add(Flatten())
    # - Flatten layer converts the 2D feature maps to a 1D feature vector for the fully connected layers

    # 30% Dropout Layer
    model.add(Dropout(0.3))
    # - Dropout layer with a rate of 0.3 for regularization before the final output layer

    model.add(Dense(2, activation='softmax'))
    #model.add(Dense(1, activation='sigmoid'))
    # - Dense layer with 2 neurons, corresponding to the number of classes in a binary classification task
    # - Softmax activation is used to output probabilities for each class

    return model
    # - The function returns the compiled CNN model

# %%
#### Because the datasets are heavily imbalanced, we used weighted_categorical_crossentropy by calculating each class weight

#weights_array = np.array([class_weights[0], class_weights[1]])

def compute_class_weight_data(labels):
    # Get the unique classes
    classes = np.unique(labels)

    # Compute the class weights
    class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=labels)

    # Convert to dictionary format for use in loss function
    class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}
    weights_array = np.array([class_weights[0], class_weights[1]])

    print("Class Weights:", weights_array)
    return weights_array

def weighted_categorical_crossentropy(weights):
    weights = K.variable(weights)

    def loss(y_true, y_pred):
        y_pred /= K.sum(y_pred, axis=-1, keepdims=True)
        y_pred = K.clip(y_pred, K.epsilon(), 1 - K.epsilon())
        _loss = y_true * K.log(y_pred) * weights
        _loss = -K.sum(_loss, -1)
        return _loss

    return loss

# %%
#this function is needed to extract the information from the dataframe

def extract_df(df, indices):
    # If no specific indices are provided (indices is None), extract all data
    if indices is None:
        # Convert the 'Segment' column into a 2D NumPy array (using vstack for vertical stacking)
        segments = np.vstack(df['Segment'].values)
        # Extract 'ValenceLabel' and 'ArousalLabel' columns as arrays
        valence_labels = df['ValenceLabel'].values
        arousal_labels = df['ArousalLabel'].values
        relaxation_labels = df['RelaxationLabel'].values
    else:
        # If indices are provided, extract only the specified rows (using iloc for positional indexing)
        segments = np.vstack(df.iloc[indices]['Segment'].values)
        valence_labels = df.iloc[indices]['ValenceLabel'].values
        arousal_labels = df.iloc[indices]['ArousalLabel'].values
        relaxation_labels = df.iloc[indices]['RelaxationLabel'].values

    # Stack valence and arousal labels vertically and transpose them (labels become a 2D array with two columns)
    labels = np.vstack((valence_labels, arousal_labels, relaxation_labels)).T
    # Return the segments (features) and the corresponding labels
    return segments, labels

# %%
def create_directory_if_not_exists(directory_path):
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)

def run_experiment_hyperparameter(
    df_segments,
    segment_length_samp,
    model_builder,                     # <-- keep the refactor: pass a function that returns a compiled model
    save_path,
    epochs,
    num_classes=2,
    activation_type="softmax",
    loss_function="weighted_categorical",
    target_label="Valence",            # <-- "Valence" or "Arousal"
):
    """
    Runs 5-fold CV with subject-level splitting (no leakage).
    - `model_builder(segment_length_samp)` must return an uncompiled Keras model.
    - Set `activation_type="softmax"` for 2 outputs (one-hot), or "sigmoid" for single-output binary.
    - `loss_function="weighted_categorical"` enables class weighting for the chosen target.
    """
    loss_function_load = None

    # --- target selection (0: Valence, 1: Arousal) ---
    t = str(target_label).strip().lower()
    label_map = {"valence": 0, "arousal": 1, "relaxation": 2}
    if t not in label_map:
        raise ValueError("target_label must be 'Valence' or 'Arousal'or 'Relaxation' ")
    col_idx = label_map[t]
    print(f"Running target: {t.title()} (column {col_idx})")

    results = []
    unique_subject_ids = df_segments['SubjectID'].unique()
    kf = KFold(n_splits=5, shuffle=True, random_state=42)

    for fold_idx, (train_idx, test_idx) in enumerate(kf.split(unique_subject_ids)):
        print(f"\n==== Fold {fold_idx + 1} ({t.title()}) ====")

        train_subjects = unique_subject_ids[train_idx]
        test_subjects  = unique_subject_ids[test_idx]

        train_df = df_segments[df_segments['SubjectID'].isin(train_subjects)]
        test_df  = df_segments[df_segments['SubjectID'].isin(test_subjects)]

        print(f"Running experiment with batch size {BATCH_SIZE} and learning rate {LEARNING_RATE}")

        # Reset graph/session for cleanliness across folds
        tf.keras.backend.clear_session()

        # Extract data
        train_segments, train_labels = extract_df(train_df, None)
        test_segments,  test_labels  = extract_df(test_df, None)

        y_train = train_labels[:, col_idx].astype(int)
        y_test  = test_labels[:,  col_idx].astype(int)

        # Optional class weighting for chosen target
        if loss_function == "weighted_categorical":
            class_weights = compute_class_weight_data(y_train)
            loss_function_load = "weighted_categorical"
            loss_fn = weighted_categorical_crossentropy(class_weights)
            print("loss_function is weighted_categorical")
        else:
            loss_fn = loss_function

        print(f"Train segments shape: {train_segments.shape}")
        print(f"Test segments shape:  {test_segments.shape}")

        # Encode targets depending on head type
        if activation_type == "softmax":
            y_train_encoded = to_categorical(y_train, num_classes=num_classes)
            y_test_encoded  = to_categorical(y_test,  num_classes=num_classes)
        else:
            # sigmoid case: keep 0/1
            y_train_encoded = y_train
            y_test_encoded  = y_test

        print("y_train shape:", np.shape(y_train_encoded))
        print("y_test shape:",  np.shape(y_test_encoded))

        # ---- Build & compile model via the injected builder ----
        model = model_builder(segment_length_samp)  # <-- your factory, e.g., create_cnn_lstm_model
        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
            loss=loss_fn,
            metrics=['accuracy']
        )

        # Unique checkpoint per target/fold config
        filepath = f"/content/drive/MyDrive/i2mtc-2026/Dataframes/ModelCheckpointLogs/i2mtc_ML_models/weights-best-{t}-{BATCH_SIZE}-{LEARNING_RATE}.keras"
        if os.path.exists(filepath):
            os.remove(filepath)

        checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
        early_stop = EarlyStopping(monitor='val_accuracy', patience=80, verbose=1)
        callbacks_list = [checkpoint, early_stop]

        # Train
        history = model.fit(
            train_segments, y_train_encoded,
            epochs=epochs,
            batch_size=BATCH_SIZE,
            validation_data=(test_segments, y_test_encoded),
            callbacks=callbacks_list
        )

        # Reload best model
        if loss_function_load == "weighted_categorical":
            best_model = tf.keras.models.load_model(
                filepath,
                custom_objects={'loss': weighted_categorical_crossentropy(class_weights)}
            )
        else:
            best_model = tf.keras.models.load_model(filepath)

        # Evaluate
        val_loss, val_accuracy = best_model.evaluate(test_segments, y_test_encoded, verbose=0)
        pred_test_probs = best_model.predict(test_segments)

        # --- Binary predictions + AUC ---
        if activation_type == "softmax":
            pred_test_labels = np.argmax(pred_test_probs, axis=1)
            true_test_labels = y_test
            pos_probs = pred_test_probs[:, 1] if pred_test_probs.shape[1] == 2 else pred_test_probs.ravel()
            auc = roc_auc_score(true_test_labels, pos_probs) if len(np.unique(true_test_labels)) == 2 else None
        else:
            pos_probs = pred_test_probs.ravel()
            pred_test_labels = (pos_probs > 0.5).astype(int)
            true_test_labels = y_test
            auc = roc_auc_score(true_test_labels, pos_probs) if len(np.unique(true_test_labels)) == 2 else None

        precision, recall, f1, support = precision_recall_fscore_support(true_test_labels, pred_test_labels, average=None)
        f1_c0 = f1[0] if len(f1) > 0 else np.nan
        f1_c1 = f1[1] if len(f1) > 1 else np.nan
        print(f"[{t.title()}] F1 per class: 0={f1_c0:.4f}, 1={f1_c1:.4f}")

        results.append({
            'target': t,
            'batch_size': BATCH_SIZE,
            'learning_rate': LEARNING_RATE,
            'train_loss': history.history.get('loss', [None])[-1],
            'train_accuracy': history.history.get('accuracy', [None])[-1],
            'val_loss': val_loss,
            'val_accuracy': val_accuracy,
            'auc': auc,
            'unweighted_F1_class_0': f1_c0,
            'unweighted_F1_class_1': f1_c1,
        })

        print(f"Completed fold with batch size {BATCH_SIZE} and learning rate {LEARNING_RATE}")

    # ---- Aggregate & save ----
    if results:
        avg_train_loss = np.nanmean([r['train_loss'] for r in results])
        avg_train_accuracy = np.nanmean([r['train_accuracy'] for r in results])
        avg_val_loss = np.nanmean([r['val_loss'] for r in results])
        avg_val_accuracy = np.nanmean([r['val_accuracy'] for r in results])
        aucs = [r['auc'] for r in results if r['auc'] is not None]
        avg_auc = np.mean(aucs) if aucs else np.nan
        avg_unweighted_f1_class_0 = np.nanmean([r['unweighted_F1_class_0'] for r in results])
        avg_unweighted_f1_class_1 = np.nanmean([r['unweighted_F1_class_1'] for r in results])

        print(f"[{t.title()}] Overall Results:")
        print(f"Average Train Loss: {avg_train_loss:.4f}")
        print(f"Average Train Accuracy: {avg_train_accuracy:.4f}")
        print(f"Average Val Loss: {avg_val_loss:.4f}")
        print(f"Average Val Accuracy: {avg_val_accuracy:.4f}")
        print(f"Average AUC: {avg_auc:.4f}")
        print(f"Average Unweighted F1 Score Class 0: {avg_unweighted_f1_class_0:.4f}")
        print(f"Average Unweighted F1 Score Class 1: {avg_unweighted_f1_class_1:.4f}")

        df_metrics = pd.DataFrame(results)
        create_directory_if_not_exists(os.path.dirname(save_path))
        df_metrics.to_csv(save_path, index=False)
        print(f"Metrics saved to {save_path}")
    else:
        print("No results to summarize. Exiting...")

    return results

# %%
LEARNING_RATE: float = 0.001
EPOCHS:        int = 350
BATCH_SIZE:    int = 512
# you can use binary_crossentropy as a loss_function if you don't want to use the weighted one.

print ("For Relaxation")
save_path = '/content/drive/MyDrive/i2mtc-2026/Dataframes/Models_Results/WARM-VR/cnn_60s_model/train_val_df/5-folds-split/cnn_60s_model_metrics_softmax_results_60s_5s-0-001_Rel.csv'
result = run_experiment_hyperparameter(shuffled_df_segments_combined, segment_length_samples, cnn_60s_model, save_path, EPOCHS, target_label="Relaxation", num_classes=2, activation_type="softmax", loss_function="weighted_categorical")


print ("For Arousal")
save_path = '/content/drive/MyDrive/i2mtc-2026/Dataframes/Models_Results/WARM-VR/cnn_60s_model/train_val_df/5-folds-split/cnn_60s_model_metrics_softmax_results_60s_5s-0-001_Aro.csv'
result = run_experiment_hyperparameter(shuffled_df_segments_combined, segment_length_samples, cnn_60s_model, save_path, EPOCHS, target_label="Arousal", num_classes=2, activation_type="softmax", loss_function="weighted_categorical")

print ("For Valence")
save_path = '/content/drive/MyDrive/i2mtc-2026/Dataframes/Models_Results/WARM-VR/cnn_60s_model/train_val_df/5-folds-split/cnn_60s_model_metrics_softmax_results_60s_5s-0-001_Val.csv'
result = run_experiment_hyperparameter(shuffled_df_segments_combined, segment_length_samples, cnn_60s_model, save_path, EPOCHS, target_label="Valence", num_classes=2, activation_type="softmax", loss_function="weighted_categorical")
# Out:
# Streaming output truncated to the last 5000 lines.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8716 - loss: 0.2856 - val_accuracy: 0.7533 - val_loss: 1.3552
# Epoch 132/350
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8750 - loss: 0.2856
# Epoch 132: val_accuracy did not improve from 0.79094
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8729 - loss: 0.2857 - val_accuracy: 0.7729 - val_loss: 1.2683
# Epoch 133/350
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8729 - loss: 0.2888
# Epoch 133: val_accuracy did not improve from 0.79094
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8727 - loss: 0.2881 - val_accuracy: 0.7626 - val_loss: 1.3037
# Epoch 134/350
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8785 - loss: 0.2774
# Epoch 134: val_accuracy did not improve from 0.79094
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8785 - loss: 0.2758 - val_accuracy: 0.7522 - val_loss: 1.3018
# Epoch 135/350
#  6/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8794 - loss: 0.2836
# Epoch 135: val_accuracy did not improve from 0.79094
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8775 - loss: 0.2813 - val_accuracy: 0.7631 - val_loss: 1.3176
# Epoch 136/350
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8857 - loss: 0.2608
# Epoch 136: val_accuracy did not improve from 0.79094
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8847 - loss: 0.2630 - val_accuracy: 0.7500 - val_loss: 1.3444
# Epoch 137/350
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8798 - loss: 0.2875
# Epoch 137: val_accuracy did not improve from 0.79094
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8788 - loss: 0.2856 - val_accuracy: 0.7467 - val_loss: 1.3210
# Epoch 138/350
#  7/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8759 - loss: 0.2959
# Epoch 138: val_accuracy did not improve from 0.79094
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8762 - loss: 0.2906 - val_accuracy: 0.7495 - val_loss: 1.3209
# Epoch 138: early stopping
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [Arousal] F1 per class: 0=0.8321, 1=0.7231
# Completed fold with batch size 512 and learning rate 0.001
#
# ==== Fold 3 (Arousal) ====
# Running experiment with batch size 512 and learning rate 0.001
# Class Weights: [0.90615224 1.11553273]
# loss_function is weighted_categorical
# Train segments shape: (5214, 3840)
# Test segments shape:  (1313, 3840)
# y_train shape: (5214, 2)
# y_test shape: (1313, 2)
# Epoch 1/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5472 - loss: 0.6871
# Epoch 1: val_accuracy improved from -inf to 0.65118, saving model to /content/drive/MyDrive/i2mtc-2026/Dataframes/ModelCheckpointLogs/i2mtc_ML_models/weights-best-arousal-512-0.001.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.5587 - loss: 0.6835 - val_accuracy: 0.6512 - val_loss: 0.6693
# Epoch 2/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5874 - loss: 0.6711
# Epoch 2: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5931 - loss: 0.6678 - val_accuracy: 0.6390 - val_loss: 0.6747
# Epoch 3/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6208 - loss: 0.6528
# Epoch 3: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6268 - loss: 0.6490 - val_accuracy: 0.6458 - val_loss: 0.6646
# Epoch 4/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6388 - loss: 0.6327
# Epoch 4: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6425 - loss: 0.6299 - val_accuracy: 0.6474 - val_loss: 0.6551
# Epoch 5/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6553 - loss: 0.6197
# Epoch 5: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.
350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8847 - loss: 0.2637
# Epoch 71: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8795 - loss: 0.2712 - val_accuracy: 0.4494 - val_loss: 1.4792
# Epoch 72/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8774 - loss: 0.2735
# Epoch 72: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8750 - loss: 0.2810 - val_accuracy: 0.4364 - val_loss: 1.5317
# Epoch 73/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8748 - loss: 0.2801
# Epoch 73: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8740 - loss: 0.2802 - val_accuracy: 0.4288 - val_loss: 1.5584
# Epoch 74/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8807 - loss: 0.2714
# Epoch 74: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8774 - loss: 0.2784 - val_accuracy: 0.4128 - val_loss: 1.6842
# Epoch 75/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8773 - loss: 0.2720
# Epoch 75: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8771 - loss: 0.2726 - val_accuracy: 0.4265 - val_loss: 1.5647
# Epoch 76/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8926 - loss: 0.2571
# Epoch 76: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8871 - loss: 0.2658 - val_accuracy: 0.4318 - val_loss: 1.5719
# Epoch 77/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8838 - loss: 0.2658
# Epoch 77: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8816 - loss: 0.2729 - val_accuracy: 0.4455 - val_loss: 1.5139
# Epoch 78/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8889 - loss: 0.2592
# Epoch 78: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8887 - loss: 0.2597 - val_accuracy: 0.4524 - val_loss: 1.5394
# Epoch 79/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8897 - loss: 0.2595
# Epoch 79: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8838 - loss: 0.2693 - val_accuracy: 0.4509 - val_loss: 1.5918
# Epoch 80/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8975 - loss: 0.2537
# Epoch 80: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8912 - loss: 0.2619 - val_accuracy: 0.4189 - val_loss: 1.6650
# Epoch 81/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9067 - loss: 0.2362
# Epoch 81: val_accuracy did not improve from 0.65118
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8984 - loss: 0.2455 - val_accuracy: 0.4372 - val_loss: 1.5955
# Epoch 81: early stopping
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# [Arousal] F1 per class: 0=0.0418, 1=0.7868
# Completed fold with batch size 512 and learning rate 0.001
#
# ==== Fold 4 (Arousal) ====
# Running experiment with batch size 512 and learning rate 0.001
# Class Weights: [0.87591473 1.16504444]
# loss_function is weighted_categorical
# Train segments shape: (5506, 3840)
# Test segments shape:  (1021, 3840)
# y_train shape: (5506, 2)
# y_test shape: (1021, 2)
# Epoch 1/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5159 - loss: 0.7141
# Epoch 1: val_accuracy improved from -inf to 0.76787, saving model to /content/drive/MyDrive/i2mtc-2026/Dataframes/ModelCheckpointLogs/i2mtc_ML_models/weights-best-arousal-512-0.001.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.5325 - loss: 0.7020 - val_accuracy: 0.7679 - val_loss: 0.7068
# Epoch 2/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5700 - loss: 0.6758
# Epoch 2: val_accuracy improved from 0.76787 to 0.79726, saving model to /content/drive/MyDrive/i2mtc-2026/Dataframes/ModelCheckpointLogs/i2mtc_ML_models/weights-best-arousal-512-0.001.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.5726 - loss: 0.6719 - val_accuracy: 0.7973 - val_loss: 0.7092
# Epoch 3/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6018 - loss: 0.6575
# Epoch 3: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5976 - loss: 0.6540 - val_accuracy: 0.7973 - val_loss: 0.6753
# Epoch 4/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6081 - loss: 0.6384
# Epoch 4: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6079 - loss: 0.6362 - val_accuracy: 0.7924 - val_loss: 0.6538
# Epoch 5/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6097 - loss: 0.6295
# Epoch 5: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6084 - loss: 0.6279 - val_accuracy: 0.7845 - val_loss: 0.6320
# Epoch 6/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.
350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8627 - loss: 0.3002
# Epoch 71: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8613 - loss: 0.3004 - val_accuracy: 0.6082 - val_loss: 1.6665
# Epoch 72/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8585 - loss: 0.3266
# Epoch 72: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8598 - loss: 0.3194 - val_accuracy: 0.5534 - val_loss: 1.7004
# Epoch 73/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8609 - loss: 0.3151
# Epoch 73: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8621 - loss: 0.3075 - val_accuracy: 0.5700 - val_loss: 1.7661
# Epoch 74/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8529 - loss: 0.3171
# Epoch 74: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8560 - loss: 0.3105 - val_accuracy: 0.5906 - val_loss: 1.7184
# Epoch 75/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8589 - loss: 0.3195
# Epoch 75: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8599 - loss: 0.3123 - val_accuracy: 0.5642 - val_loss: 1.6983
# Epoch 76/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8622 - loss: 0.3050
# Epoch 76: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8637 - loss: 0.2986 - val_accuracy: 0.5906 - val_loss: 1.7043
# Epoch 77/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8616 - loss: 0.3089
# Epoch 77: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8641 - loss: 0.3040 - val_accuracy: 0.5671 - val_loss: 1.8231
# Epoch 78/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8665 - loss: 0.3023
# Epoch 78: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8712 - loss: 0.2927 - val_accuracy: 0.5975 - val_loss: 1.7255
# Epoch 79/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8639 - loss: 0.2977
# Epoch 79: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8662 - loss: 0.2946 - val_accuracy: 0.5955 - val_loss: 1.7596
# Epoch 80/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8653 - loss: 0.2842
# Epoch 80: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8679 - loss: 0.2799 - val_accuracy: 0.6200 - val_loss: 1.6997
# Epoch 81/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8599 - loss: 0.3067
# Epoch 81: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8632 - loss: 0.3019 - val_accuracy: 0.6161 - val_loss: 1.7111
# Epoch 82/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8740 - loss: 0.2863
# Epoch 82: val_accuracy did not improve from 0.79726
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8758 - loss: 0.2831 - val_accuracy: 0.5397 - val_loss: 1.8696
# Epoch 82: early stopping
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# [Arousal] F1 per class: 0=0.0190, 1=0.8869
# Completed fold with batch size 512 and learning rate 0.001
#
# ==== Fold 5 (Arousal) ====
# Running experiment with batch size 512 and learning rate 0.001
# Class Weights: [1.01433358 0.98606587]
# loss_function is weighted_categorical
# Train segments shape: (5449, 3840)
# Test segments shape:  (1078, 3840)
# y_train shape: (5449, 2)
# y_test shape: (1078, 2)
# Epoch 1/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5235 - loss: 0.7022
# Epoch 1: val_accuracy improved from -inf to 0.40167, saving model to /content/drive/MyDrive/i2mtc-2026/Dataframes/ModelCheckpointLogs/i2mtc_ML_models/weights-best-arousal-512-0.001.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.5375 - loss: 0.6948 - val_accuracy: 0.4017 - val_loss: 0.7058
# Epoch 2/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5832 - loss: 0.6736
# Epoch 2: val_accuracy did not improve from 0.40167
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5878 - loss: 0.6713 - val_accuracy: 0.3942 - val_loss: 0.7129
# Epoch 3/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6055 - loss: 0.6566
# Epoch 3: val_accuracy did not improve from 0.40167
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6094 - loss: 0.6538 - val_accuracy: 0.3942 - val_loss: 0.7306
# Epoch 4/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6118 - loss: 0.6372
# Epoch 4: val_accuracy did not improve from 0.40167
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6156 - loss: 0.6345 - val_accuracy: 0.3952 - val_loss: 0.7748
# Epoch 5/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6153 - loss: 0.6240
# Epoch 5: val_accuracy did not improve from 0.40167
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9373 - loss: 0.1476 - val_accuracy: 0.7032 - val_loss: 1.1716
# Epoch 305/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9362 - loss: 0.1526
# Epoch 305: val_accuracy did not improve from 0.75510
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9365 - loss: 0.1519 - val_accuracy: 0.7328 - val_loss: 1.2644
# Epoch 306/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9392 - loss: 0.1453
# Epoch 306: val_accuracy did not improve from 0.75510
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9419 - loss: 0.1412 - val_accuracy: 0.7254 - val_loss: 1.3933
# Epoch 307/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9318 - loss: 0.1596
# Epoch 307: val_accuracy improved from 0.75510 to 0.75974, saving model to /content/drive/MyDrive/i2mtc-2026/Dataframes/ModelCheckpointLogs/i2mtc_ML_models/weights-best-valence-512-0.001.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9322 - loss: 0.1587 - val_accuracy: 0.7597 - val_loss: 1.2272
# Epoch 308/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9398 - loss: 0.1456
# Epoch 308: val_accuracy did not improve from 0.75974
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9400 - loss: 0.1451 - val_accuracy: 0.7505 - val_loss: 1.2109
# Epoch 309/350
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9480 - loss: 0.1234
# Epoch 309: val_accuracy improved from 0.75974 to 0.76345, saving model to /content/drive/MyDrive/i2mtc-2026/Dataframes/ModelCheckpointLogs/i2mtc_ML_models/weights-best-valence-512-0.001.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9481 - loss: 0.1231 - val_accuracy: 0.7635 - val_loss: 1.3099
# Epoch 310/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9432 - loss: 0.1373
# Epoch 310: val_accuracy did not improve from 0.76345
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9423 - loss: 0.1380 - val_accuracy: 0.7597 - val_loss: 1.4524
# Epoch 311/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9363 - loss: 0.1576
# Epoch 311: val_accuracy did not improve from 0.76345
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9376 - loss: 0.1522 - val_accuracy: 0.7403 - val_loss: 1.1773
# Epoch 312/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9433 - loss: 0.1412
# Epoch 312: val_accuracy did not improve from 0.76345
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9444 - loss: 0.1408 - val_accuracy: 0.7096 - val_loss: 1.2833
# Epoch 313/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9375 - loss: 0.1445
# Epoch 313: val_accuracy did not improve from 0.76345
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9379 - loss: 0.1464 - val_accuracy: 0.7328 - val_loss: 1.3014
# Epoch 314/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9384 - loss: 0.1419
# Epoch 314: val_accuracy did not improve from 0.76345
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9386 - loss: 0.1452 - val_accuracy: 0.7347 - val_loss: 1.2107
# Epoch 315/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9304 - loss: 0.1424
# Epoch 315: val_accuracy did not improve from 0.76345
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9335 - loss: 0.1437 - val_accuracy: 0.7059 - val_loss: 1.2394
# Epoch 316/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9415 - loss: 0.1389
# Epoch 316: val_accuracy did not improve from 0.76345
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9436 - loss: 0.1383 - val_accuracy: 0.7273 - val_loss: 1.2835
# Epoch 317/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9492 - loss: 0.1278
# Epoch 317: val_accuracy did not improve from 0.76345
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9491 - loss: 0.1299 - val_accuracy: 0.7180 - val_loss: 1.3525
# Epoch 318/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9410 - loss: 0.1441
# Epoch 318: val_accuracy did not improve from 0.76345
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9422 - loss: 0.1429 - val_accuracy: 0.7152 - val_loss: 1.3048
# Epoch 319/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9312 - loss: 0.1499
# Epoch 319: val_accuracy did not improve from 0.76345
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9365 - loss: 0.1441 - val_accuracy: 0.7430 - val_loss: 1.3498
# Epoch 320/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9411 - loss: 0.1399
# Epoch 320: val_accuracy did not improve from 0.76345
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.
350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9464 - loss: 0.1276
# Epoch 337: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9467 - loss: 0.1284 - val_accuracy: 0.7310 - val_loss: 1.3256
# Epoch 338/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9421 - loss: 0.1479
# Epoch 338: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9422 - loss: 0.1463 - val_accuracy: 0.7199 - val_loss: 1.2524
# Epoch 339/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9365 - loss: 0.1495
# Epoch 339: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9392 - loss: 0.1469 - val_accuracy: 0.7365 - val_loss: 1.2035
# Epoch 340/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9460 - loss: 0.1436
# Epoch 340: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9465 - loss: 0.1416 - val_accuracy: 0.7291 - val_loss: 1.2016
# Epoch 341/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9422 - loss: 0.1319
# Epoch 341: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9459 - loss: 0.1283 - val_accuracy: 0.7375 - val_loss: 1.2867
# Epoch 342/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9395 - loss: 0.1390
# Epoch 342: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9424 - loss: 0.1348 - val_accuracy: 0.7653 - val_loss: 1.2938
# Epoch 343/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9461 - loss: 0.1407
# Epoch 343: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9473 - loss: 0.1351 - val_accuracy: 0.7532 - val_loss: 1.1673
# Epoch 344/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9446 - loss: 0.1280
# Epoch 344: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9467 - loss: 0.1277 - val_accuracy: 0.7449 - val_loss: 1.1458
# Epoch 345/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9419 - loss: 0.1412
# Epoch 345: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9436 - loss: 0.1385 - val_accuracy: 0.7588 - val_loss: 1.1664
# Epoch 346/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9455 - loss: 0.1295
# Epoch 346: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9455 - loss: 0.1318 - val_accuracy: 0.7273 - val_loss: 1.2406
# Epoch 347/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9437 - loss: 0.1406
# Epoch 347: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9442 - loss: 0.1380 - val_accuracy: 0.7254 - val_loss: 1.2228
# Epoch 348/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9403 - loss: 0.1375
# Epoch 348: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9434 - loss: 0.1336 - val_accuracy: 0.7263 - val_loss: 1.2515
# Epoch 349/350
#  7/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9480 - loss: 0.1291
# Epoch 349: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9468 - loss: 0.1296 - val_accuracy: 0.7393 - val_loss: 1.2071
# Epoch 350/350
#  6/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9586 - loss: 0.1129
# Epoch 350: val_accuracy did not improve from 0.77087
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9593 - loss: 0.1141 - val_accuracy: 0.7180 - val_loss: 1.3040
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# [Valence] F1 per class: 0=0.4990, 1=0.8515
# Completed fold with batch size 512 and learning rate 0.001
# [Valence] Overall Results:
# Average Train Loss: 0.2048
# Average Train Accuracy: 0.9100
# Average Val Loss: 1.0605
# Average Val Accuracy: 0.6419
# Average AUC: 0.6179
# Average Unweighted F1 Score Class 0: 0.4645
# Average Unweighted F1 Score Class 1: 0.7130
# Metrics saved to /content/drive/MyDrive/i2mtc-2026/Dataframes/Models_Results/WARM-VR/create_cnn_GRU_model_32/train_val_df/5-folds-split/create_cnn_GRU_model_32_metrics_softmax_results_60s_5s-0-001_Val.csv
